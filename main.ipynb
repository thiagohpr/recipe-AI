# %%
import os

path = "dataset\\train\\"

file_list = []

for root, dirs, files in os.walk(path):
#     print('Root : ', root)
#     print('Dirs : ', dirs)
#     print('Files : ', files)
    for file in files:
        file_list.append(os.path.join(root, file))

file_list
# Out:
# ['dataset\\train\\Abacaxi.JPEG',
#  'dataset\\train\\Abacaxi2.JPEG',
#  'dataset\\train\\Abacaxi3.JPEG',
#  'dataset\\train\\Abacaxi4.JPEG',
#  'dataset\\train\\Abobrinha.JPEG',
#  'dataset\\train\\Abobrinha2.JPEG',
#  'dataset\\train\\Abobrinha3.JPEG',
#  'dataset\\train\\Alface.JPEG',
#  'dataset\\train\\Alface2.JPEG',
#  'dataset\\train\\Alface3.JPEG',
#  'dataset\\train\\Alho.JPEG',
#  'dataset\\train\\Alho2.JPEG',
#  'dataset\\train\\Alho3.JPEG',
#  'dataset\\train\\Arroz.JPEG',
#  'dataset\\train\\Arroz2.JPEG',
#  'dataset\\train\\Arroz3.JPEG',
#  'dataset\\train\\Aveia.JPEG',
#  'dataset\\train\\Aveia2.JPEG',
#  'dataset\\train\\Aveia3.JPEG',
#  'dataset\\train\\Bacon.JPEG',
#  'dataset\\train\\Bacon2.JPEG',
#  'dataset\\train\\Bacon3.JPEG',
#  'dataset\\train\\Bacon4.JPEG',
#  'dataset\\train\\Banana.JPEG',
#  'dataset\\train\\Banana2.JPEG',
#  'dataset\\train\\Banana3.JPEG',
#  'dataset\\train\\Batata.JPEG',
#  'dataset\\train\\Batata2.JPEG',
#  'dataset\\train\\Batata3.JPEG',
#  'dataset\\train\\Batata4.JPEG',
#  'dataset\\train\\Biscoito_oreo.JPEG',
#  'dataset\\train\\Biscoito_oreo2.JPEG',
#  'dataset\\train\\Biscoito_oreo3.JPEG',
#  'dataset\\train\\Biscoito_oreo4.JPEG',
#  'dataset\\train\\Brocolis.JPEG',
#  'dataset\\train\\Brocolis2.JPEG',
#  'dataset\\train\\Brocolis3.JPEG',
#  'dataset\\train\\Brocolis4.JPEG',
#  'dataset\\train\\Chocolate_ao_leite.JPEG',
#  'dataset\\train\\Chocolate_ao_leite2.JPEG',
#  'dataset\\train\\Chocolate_ao_leite3.JPEG',
#  'dataset\\train\\Chocolate_ao_leite4.JPEG',
#  'dataset\\train\\Chocolate_ao_leite5.JPEG',
#  'dataset\\train\\Couve_flor.JPEG',
#  'dataset\\train\\Couve_flor2.JPEG',
#  'dataset\\train\\Couve_flor3.JPEG',
#  'dataset\\train\\File_mignon.JPEG',
#  'dataset\\train\\File_mignon2.JPEG',
#  'dataset\\train\\File_mignon3.JPEG',
#  'dataset\\train\\Ketchup.JPEG',
#  'dataset\\train\\Ketchup2.JPEG',
#  'dataset\\train\\Ketchup3.JPEG',
#  'dataset\\train\\Ketchup4.JPEG',
#  'dataset\\train\\Laranja.JPEG',
#  'dataset\\train\\Laranja2.JPEG',
#  'dataset\\train\\Laranja3.JPEG',
#  'dataset\\train\\Leite.JPEG',
#  'dataset\\train\\Leite2.JPEG',
#  'dataset\\train\\Leite3.JPEG',
#  'dataset\\train\\Leite4.JPEG',
#  'dataset\\train\\Limao.JPEG',
#  'dataset\\train\\Limao2.JPEG',
#  'dataset\\train\\Limao3.JPEG',
#  'dataset\\train\\Linguiça.JPEG',
#  'dataset\\train\\Linguiça2.JPEG',
#  'dataset\\train\\Linguiça3.JPEG',
#  'dataset\\train\\Linguiça4.JPEG',
#  'dataset\\train\\Maca.JPEG',
#  'dataset\\train\\Maca2.JPEG',
#  'dataset\\train\\Maca3.JPEG',
#  'dataset\\train\\Maca4.JPEG',
#  'dataset\\train\\Maca5.JPEG',
#  'dataset\\train\\Macarrao.JPEG',
#  'dataset\\train\\Macarrao2.JPEG',
#  'dataset\\train\\Macarrao3.JPEG',
#  'dataset\\train\\Macarrao4.JPEG',
#  'dataset\\train\\Manteiga.JPEG',
#  'dataset\\train\\Manteiga2.JPEG',
#  'dataset\\train\\Manteiga3.JPEG',
#  'dataset\\train\\Manteiga4.JPEG',
#  'dataset\\train\\Mortadela.JPEG',
#  'dataset\\train\\Mortadela2.JPEG',
#  'dataset\\train\\Mortadela3.JPEG',
#  'dataset\\train\\Mostarda2.JPEG',
#  'dataset\\train\\Mostarda3.JPEG',
#  'dataset\\train\\Mostrada.JPEG',
#  'dataset\\train\\Ovos.JPEG',
#  'dataset\\train\\Ovos2.JPEG',
#  'dataset\\train\\Ovos3.JPEG',
#  'dataset\\train\\Pao_de_forma.JPEG',
#  'dataset\\train\\Pao_de_forma2.JPEG',
#  'dataset\\train\\Pao_de_forma3.JPEG',
#  'dataset\\train\\Pera.JPEG',
#  'dataset\\train\\Pera2.JPEG',
#  'dataset\\train\\Pera3.JPEG',
#  'dataset\\train\\Pera4.JPEG',
#  'dataset\\train\\Pera5.JPEG',
#  'dataset\\train\\Queijo_mussarela.JPEG',
#  'dataset\\train\\Queijo_mussarela2.JPEG',
#  'dataset\\train\\Queijo_mussarela3.JPEG',
#  'dataset\\train\\Queijo_mussarela4.JPEG',
#  'dataset\\train\\Salmão.JPEG',
#  'dataset\\train\\Salmão2.JPEG',
#  'dataset\\train\\Salmão3.JPEG',
#  'dataset\\train\\Salmão4.JPEG',
#  'dataset\\train\\Sobrecoxa_de_frango.JPEG',
#  'dataset\\train\\Sobrecoxa_de_frango2.JPEG',
#  'dataset\\train\\Sobrecoxa_de_frango3.JPEG',
#  'dataset\\train\\Sobrecoxa_de_frango4.JPEG',
#  'dataset\\train\\Sucrilhos.JPEG',
#  'dataset\\train\\Sucrilhos2.JPEG',
#  'dataset\\train\\Sucrilhos3.JPEG',
#  'dataset\\train\\Sucrilhos4.JPEG',
#  'dataset\\train\\Tomate.JPEG',
#  'dataset\\train\\Tomate2.JPEG',
#  'dataset\\train\\Tomate3.JPEG']

# %%
import numpy as np  
import pandas as pd  

import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import glob # to find files recursively

# import keras 
# import tensorflow as tf

# from tensorflow.keras.preprocessing import image_dataset_from_directory
